# %%
import re
import pandas as pd
import json

# %%
data = {}

with open ('input-data/iframes.md') as f:
    f=f.read()
    for line in f.strip().splitlines():
        line=line.strip()
        if not line:
            continue
        if line.endswith(":") and not line.strip().startswith("{{"):
            path=line[:-1]
            data[path] = []
        else:
            full = re.match(r"(\d+):\s*(.+)", line)
            # iframe = re.search(r"(?<=\{\{).*?(?=\}\})", line)
            if full and path:
                # type = full.group(0).split(" ")[1]
                if not type.startswith("/"):
                    line_number = int(full.group(1))
                    fullcontent = full.group(2).strip()
                    data[path].append({
                        "line": line_number,
                        "iframe": fullcontent
                    })

jsonOut = json.dumps(data,indent=2)

with open('dumps/iframes-dump.json', 'w') as out:
    json.dump(data, out, ensure_ascii=False,)

# %%
import csv

# %%
with open ('dumps/iframes-dump.json', 'r') as f:
    d = json.load(f)

with open('dumps/iframes-dump.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fields = ['line','iframe']
    writer = csv.DictWriter(csvfile, fieldnames=fields)

    writer.writeheader()

    for filepath, entries in d.items():
        for entry in entries:
            print(entry)
            writer.writerow({
                'line': entry['line'],
                'iframe': entry['iframe'],
            })
